# %% [markdown]
# # Asteroids, Comets, and Small Body Spitzer Dataset

# %%
import pandas as pd

import urllib.request as urllib
from bs4 import BeautifulSoup

bodies = urllib.urlopen("https://pdssbn.astro.umd.edu/data_other/Spitzer.shtml")
soup = BeautifulSoup(bodies.read())
classifications = urllib.urlopen("https://pdssbn.astro.umd.edu/data_other/objclass.shtml")
soup2 = BeautifulSoup(classifications.read())

bodydf = pd.DataFrame(columns = ["Name", "NAIF ID Number", "Classification", "Distance", "Records", "Link"])
classificationdf = pd.DataFrame(columns = ["Abbreviation", "Title", "Distance", "Description"])

# %%
atags = soup.find_all("a")
bodytypes = []

for atag in atags:
    if atag.get("href") != None:
        if "sptz_01_COMET" in atag.get("href"):
            bodytypes.append("Comet")
        elif "sptz_02_INNER" in atag.get("href"):
            bodytypes.append("Inner Solar System Asteroids")
        elif "sptz_03_MAIN" in atag.get("href"):
            bodytypes.append("Main Belt Asteroids")
        elif "sptz_04_OUTER" in atag.get("href"):
            bodytypes.append("Outer Solar System Asteroids")
        elif "sptz_05_SAT" in atag.get("href"):
            bodytypes.append("Satellite")
            
bodydf = pd.DataFrame(index = bodytypes, columns = ["Name", "NAIF ID Number", "Classification", "Records", "Link"])

# %%
trtags = soup.find_all("tr")
names = []

for tag in trtags:
    if tag.find("td").get_text() != "Object Name":
        names.append(tag.find("td").get_text())
        
bodydf["Name"] = names

# %%
trtags = soup.find_all("tr")
atags = []
idnumbers = []
for tag in trtags:
    if tag.find("a", {"onclick":"this.target='_blank'"}) != None:
        idnumbers.append(tag.find("a", {"onclick":"this.target='_blank'"}).get_text())

bodydf["NAIF ID Number"] = idnumbers

# %%
atags = soup.find_all("a")
classifications = []
for atag in atags:
    if atag.get("href") != None:
        if "objclass" in atag.get("href"):
            classifications.append(atag.get_text())

bodydf["Classification"] = classifications

# %%
trtags = soup2.find_all("tr")
classdistance = []

for trtag in trtags:
    for tdtag in (trtag.find_all("td"))[2:3]:
        if tdtag.get_text() != "Description":
            left, delimit, right = tdtag.get_text().partition("(")
            left2, delimit2, right2 = right.partition(")")
            classdistance.append(left2)

classificationdf["Distance"] = classdistance

# %%
trtags = soup.find_all("tr")
records = []

for trtag in trtags:
    for tdtag in (trtag.find_all("td"))[3:]:
        if tdtag.get_text() != "Records":
            records.append(tdtag.get_text())
            
bodydf["Records"] = records

# %%
trtags = soup.find_all("tr")
links = []

for tag in trtags:
    if tag.find("td").find("a") != None:
        links.append("https://pdssbn.astro.umd.edu/data_other/" + tag.find("td").find("a").get("href"))
    
bodydf["Link"] = links

# %%
trtags = soup2.find_all("tr")
abbreviations = []

for trtag in trtags:
    if trtag.find("td").find("a") != None:
        abbreviations.append(trtag.find("td").find("a").get("name"))

classificationdf["Abbreviation"] = abbreviations

# %%
trtags = soup2.find_all("tr")
titles = []

for trtag in trtags:
    for tdtag in (trtag.find_all("td"))[1:2]:
        if tdtag.get_text() != "Title":
            titles.append(tdtag.get_text())
            
classificationdf["Title"] = titles

# %%
trtags = soup2.find_all("tr")
descriptions = []

for trtag in trtags:
    for tdtag in (trtag.find_all("td"))[2:3]:
        if tdtag.get_text() != "Description":
            descriptions.append(tdtag.get_text())
            
classificationdf["Description"] = descriptions

# %%
bodydistance = []
abbrevstrings = []
distancestrings = []
alltuples = []

for abbrev in classificationdf["Abbreviation"]:
    abbrevstrings.append(abbrev)
for distance in classificationdf["Distance"]:
    distancestrings.append(distance)
for i in range(0, len(abbrevstrings)):
    alltuples.append((abbrevstrings[i], distancestrings[i]))

for classification in bodydf["Classification"]:
    if classification != "":
        for etuple in alltuples:
            if etuple[0] == classification:
                bodydistance.append(etuple[1])
    else:
        bodydistance.append("N/A")
            
bodydf["Distance"] = bodydistance

# %%
classificationdf
# Out:
#    Abbreviation                     Title  \
# 0           COM                     Comet
# 1           CTc         Chiron-type Comet
# 2           ETc          Encke-type Comet
# 3           HTC        Halley-type Comet*
# 4           HYP          Hyperbolic Comet
# 5           JFc      Jupiter-family Comet
# 6           JFC     Jupiter-family Comet*
# 7           PAR           Parabolic Comet
# 8           AMO                      Amor
# 9           APO                    Apollo
# 10          AST                  Asteroid
# 11          ATE                      Aten
# 12          CEN                   Centaur
# 13          HYA       Hyperbolic Asteroid
# 14          IEO     Interior Earth Object
# 15          IMB  Inner Main-belt Asteroid
# 16          MBA        Main-belt Asteroid
# 17          MCA    Mars-crossing Asteroid
# 18          OMB  Outer Main-belt Asteroid
# 19          PAA        Parabolic Asteroid
# 20          TJN            Jupiter Trojan
# 21          TNO     TransNeptunian Object
#
#                                           Description  \
# 0   Comet orbit not matching any defined orbit class.
# 1   Chiron-type comet, as defined by Levison and D...
# 2   Encke-type comet, as defined by Levison and Du...
# 3   Halley-type comet, classical definition (20 y ...
# 4              Comets on hyperbolic orbits (e > 1.0).
# 5   Jupiter-family comet, as defined by Levison an...
# 6   Jupiter-family comet, classical definition (P ...
# 7               Comets on parabolic orbits (e = 1.0).
# 8   Near-Earth asteroid orbits similar to that of ...
# 9   Near-Earth asteroid orbits which cross the Ear...
# 10  Asteroid orbit not matching any defined orbit ...
# 11  Near-Earth asteroid orbits similar to that of ...
# 12  Objects with orbits between Jupiter and Neptun...
# 13          Asteroids on hyperbolic orbits (e > 1.0).
# 14  An asteroid orbit contained entirely within th...
# 15  Asteroids with orbital elements constrained by...
# 16  Asteroids with orbital elements constrained by...
# 17  Asteroids that cross the orbit of Mars constra...
# 18  Asteroids with orbital elements constrained by...
# 19           Asteroids on parabolic orbits (e = 1.0).
# 20  Asteroids traped in Jupiter's L4/L5 Lagrange p...
# 21  Objects with orbits outside Neptune (a > 30.1 ...
#
#                              Distance
# 0
# 1          TJupiter > 3; a > aJupiter
# 2          TJupiter > 3; a < aJupiter
# 3                    20 y < P < 200 y
# 4                             e > 1.0
# 5                    2 < TJupiter < 3
# 6                            P < 20 y
# 7                             e = 1.0
# 8   a > 1.0 AU; 1.017 AU < q < 1.3 AU
# 9            a > 1.0 AU; q < 1.017 AU
# 10
# 11           a < 1.0 AU; Q > 0.983 AU
# 12               5.5 AU < a < 30.1 AU
# 13                            e > 1.0
# 14                       Q < 0.983 AU
# 15           a < 2.0 AU; q > 1.666 AU
# 16  2.0 AU < a < 3.2 AU; q > 1.666 AU
# 17  1.3 AU < q < 1.666 AU; a < 3.2 AU
# 18                3.2 AU < a < 4.6 AU
# 19                            e = 1.0
# 20       4.6 AU < a < 5.5 AU; e < 0.3
# 21                        a > 30.1 AU

# %%
bodydf
# Out:
#                                                Name           NAIF ID Number  \
# Comet              148P/Anderson-LINEAR 1 (1963 W1)                  1000328
# Comet                         50P/Arend 1 (1951 T1)                  1000001
# Comet                  49P/Arend-Rigaux 1 (1951 C2)                  1000002
# Comet              47P/Ashbrook-Jackson 1 (1948 Q1)                  1000003
# Comet                      19P/Borrelly 1 (1904 Y2)                  1000005
# Comet                        16P/Brooks 2 (1889 N1)                  1000008
# Comet                       P/Broughton 1 (2005 T5)                  1001674
# Comet                          C/Cardinal (2008 T2)                  1003000
# Comet                       P/Catalina 3 (2005 JQ5)                  1000567
# Comet                P/Catalina-NEAT 1 (2005 JD108)                  1001650
# Comet                     101P/Chernykh 1 (1977 Q1)                  1000011
# Comet                          95P/Chiron (1977 UB)                  2002060
# Comet                  210P/Christensen 1 (2003 K2)                  1000440
# Comet                  286P/Christensen 3 (2005 L4)                  1001646
# Comet                     P/Christensen 7 (2005 W2)                  1001678
# Comet                       C/Christensen (2006 W3)                  1002430
# Comet         67P/Churyumov-Gerasimenko 1 (1969 R1)  1000012,9901340,9902315
# Comet                      108P/Ciffreo 1 (1985 V1)                  1000013
# Comet                     167P/CINEOS 1 (2004 PY42)                  1001647
# Comet                         71P/Clark 1 (1973 L1)                  1000014
# Comet                    32P/Comas Sola 1 (1926 V1)                  1000015
# Comet                       6P/d'Arrest 1 (1851 M1)                  1000017
# Comet                        33P/Daniel 1 (1909 X1)                  1000018
# Comet            54P/de Vico-Swift-NEAT 1 (1844 Q1)          1000019,1000414
# Comet              72P/Denning-Fujikawa 1 (1881 T1)                  1000020
# Comet               79P/du Toit-Hartley 1 (1945 G1)                  1000022
# Comet      57P/du Toit-Neujmin-Delporte 1 (1941 O1)          1000023,1000397
# Comet                     174P/Echeclus (2000 EC98)                  2060558
# Comet                 133P/Elst-Pizarro 1 (1996 N2)                  2007968
# Comet                          2P/Encke 1 (1818 W1)                  1000025
# ...                                             ...                      ...
# Satellite                               J7 Hyperion                      607
# Satellite                                J8 Iapetus                      608
# Satellite                                J22 Ijiraq                      622
# Satellite                               J24 Iocaste                      524
# Satellite                                J26 Isonoe                      526
# Satellite                                J23 Kalyke                      523
# Satellite                                J24 Kiviuq                      624
# Satellite                                  J13 Leda                      513
# Satellite                              J10 Lysithea                      510
# Satellite                             J19 Magaclite                      519
# Satellite                                 N2 Nereid                      802
# Satellite                                 U4 Oberon                      704
# Satellite                               J20 Paaliaq                      620
# Satellite                               J8 Pasiphae                      508
# Satellite                                 J9 Phoebe                      609
# Satellite                             J27 Praxidike                      527
# Satellite                                   J5 Rhea                      605
# Satellite                               J29 Siarnaq                      629
# Satellite                                 J9 Sinope                      509
# Satellite                               U17 Sycorax                      717
# Satellite                                J21 Tarvos                      621
# Satellite                               J20 Taygete                      520
# Satellite                                 J3 Tethys                      603
# Satellite                              J18 Themisto                      518
# Satellite                                J29 Thyone                      529
# Satellite                                  J6 Titan                      606
# Satellite                                U3 Titania                      703
# Satellite                                 N1 Triton                      801
# Satellite                                U2 Umbriel                      702
# Satellite                                  J19 Ymir                      619
#
#           Classification Records  \
# Comet                JFc       3
# Comet                JFc       2
# Comet                JFc       4
# Comet                JFc       2
# Comet                JFc       2
# Comet                JFc       3
# Comet                JFc       3
# Comet                HYP       3
# Comet                JFc       2
# Comet                JFc       3
# Comet                JFc       3
# Comet                CEN       7
# Comet                JFc       2
# Comet                JFc       2
# Comet                JFc       3
# Comet                COM       4
# Comet                JFc      86
# Comet                JFc       1
# Comet                CTc       5
# Comet                JFc       6
# Comet                JFc       4
# Comet                JFc       5
# Comet                JFc       2
# Comet                JFc       2
# Comet                JFc       4
# Comet                JFc       2
# Comet                JFc       4
# Comet                CEN       9
# Comet                MBA       3
# Comet                ETc      25
# ...                  ...     ...
# Satellite                      3
# Satellite                      6
# Satellite                      3
# Satellite                      3
# Satellite                      3
# Satellite                      3
# Satellite                      3
# Satellite                      3
# Satellite                      3
# Satellite                      3
# Satellite                      2
# Satellite                      9
# Satellite                      3
# Satellite                      3
# Satellite                      9
# Satellite                      3
# Satellite                      9
# Satellite                      3
# Satellite                      3
# Satellite                      3
# Satellite                      3
# Satellite                      3
# Satellite                      4
# Satellite                      3
# Satellite                      3
# Satellite                     19
# Satellite                      9
# Satellite                      9
# Satellite                      5
# Satellite                      3
#
#                                                         Link  \
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Comet      https://pdssbn.astro.umd.edu/data_other/sptz_0...
# ...                                                      ...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
# Satellite  https://pdssbn.astro.umd.edu/data_other/sptz_0...
#
#                                     Distance
# Comet                       2 < TJupiter < 3
# Comet                       2 < TJupiter < 3
# Comet                       2 < TJupiter < 3
# Comet                       2 < TJupiter < 3
# Comet                       2 < TJupiter < 3
# Comet                       2 < TJupiter < 3
# Comet                       2 < TJupiter < 3
# Comet                                e > 1.0
# Comet                       2 < TJupiter < 3
# Comet                       2 < TJupiter < 3
# Comet                       2 < TJupiter < 3
# Comet                   5.5 AU < a < 30.1 AU
# Comet                       2 < TJupiter < 3
# Comet                       2 < TJupiter < 3
# Comet                       2 < TJupiter < 3
# Comet
# Comet                       2 < TJupiter < 3
# Comet                       2 < TJupiter < 3
# Comet             TJupiter > 3; a > aJupiter
# Comet                       2 < TJupiter < 3
# Comet                       2 < TJupiter < 3
# Comet                       2 < TJupiter < 3
# Comet                       2 < TJupiter < 3
# Comet                       2 < TJupiter < 3
# Comet                       2 < TJupiter < 3
# Comet                       2 < TJupiter < 3
# Comet                       2 < TJupiter < 3
# Comet                   5.5 AU < a < 30.1 AU
# Comet      2.0 AU < a < 3.2 AU; q > 1.666 AU
# Comet             TJupiter > 3; a < aJupiter
# ...                                      ...
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
# Satellite                                N/A
#
# [1541 rows x 6 columns]

# %%
bodydf.to_csv('res/asteroids_comets_bodies_dataset1.csv')

# %%
classificationdf.to_csv('res/classifications_dataset2.csv')
